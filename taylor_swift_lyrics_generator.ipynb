# %% [markdown]
# <a href="https://colab.research.google.com/github/bmaribeiro/clinical_specialty_classification/blob/main/taylor_swift_lyrics_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Data and Execution Time Setup

# %% [markdown]
# **Step 0**. Before running any cell in this notebook, one should set the execution time to GPU. Click in "Execution Time" --> "Change type of Execution Time" --> Select a GPU

# %% [markdown]
# **Step 1.** To install this API, run the following command:

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.6)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %% [markdown]
# **Step 2.** Next, you need an API key. You can get one of these by going to your Kaggle account settings and click on “Create New API Token”. This will download a file called “kaggle.json” to your computer.

# %% [markdown]
# **Step 3.** You should upload the "kaggle.json" file to your Google Colab. You can do this by clicking on the folder icon in the left sidebar of Colab and selecting “Upload”. (Make sure that the file is in the "root")

# %% [markdown]
# **Step 4.** Run the following cells to download the "Taylor Swift All Lyrics" dataset:

# %%
import os
os.environ["KAGGLE_CONFIG_DIR"] = "/content"

# %%
# !kaggle datasets download -d ishikajohari/taylor-swift-all-lyrics-30-albums
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# Downloading taylor-swift-all-lyrics-30-albums.zip to /content
#  49% 9.00M/18.3M [00:00<00:00, 25.8MB/s]
# 100% 18.3M/18.3M [00:00<00:00, 46.9MB/s]

# %% [markdown]
# **Step 5.** Unzip the data

# %%
# !unzip taylor-swift-all-lyrics-30-albums.zip
# Out:
# Archive:  taylor-swift-all-lyrics-30-albums.zip
#   inflating: data/Albums.csv
#   inflating: data/Albums/1989/1989_Booklet_.txt
#   inflating: data/Albums/1989/AllYouHadtoDoWasStay.txt
#   inflating: data/Albums/1989/BadBlood.txt
#   inflating: data/Albums/1989/BlankSpace.txt
#   inflating: data/Albums/1989/Clean.txt
#   inflating: data/Albums/1989/HowYouGetTheGirl.txt
#   inflating: data/Albums/1989/IKnowPlaces.txt
#   inflating: data/Albums/1989/IWishYouWould.txt
#   inflating: data/Albums/1989/OutOfTheWoods.txt
#   inflating: data/Albums/1989/ShakeItOff.txt
#   inflating: data/Albums/1989/Style.txt
#   inflating: data/Albums/1989/ThisLove.txt
#   inflating: data/Albums/1989/WelcometoNewYork.txt
#   inflating: data/Albums/1989/WildestDreams.txt
#   inflating: data/Albums/AllTooWell_10MinuteVersion__TheShortFilm__EP/AllTooWell_10MinuteVersion__TheShortFilm_.txt
#   inflating: data/Albums/Anti_Hero_Remixes_/Anti_Hero.txt
#   inflating: data/Albums/Anti_Hero_Remixes_/Anti_Hero_JaydaGRemix_.txt
#   inflating: data/Albums/Anti_Hero_Remixes_/Anti_Hero_KungsRemix_.txt
#   inflating: data/Albums/Anti_Hero_Remixes_/Anti_Hero_Remix_.txt
#   inflating: data/Albums/Anti_Hero_Remixes_/Anti_Hero_RooseveltRemix_.txt
#   inflating: data/Albums/Carolina_FromTheMotionPictureWhereTheCrawdadsSing_/Carolina.txt
#   inflating: data/Albums/Carolina_FromTheMotionPictureWhereTheCrawdadsSing_/Carolina_VideoVersion_.txt
#   inflating: data/Albums/Evermore/champagneproblems.txt
#   inflating: data/Albums/Evermore/closure.txt
#   inflating: data/Albums/Evermore/coneyisland.txt
#   inflating: data/Albums/Evermore/cowboylikeme.txt
#   inflating: data/Albums/Evermore/dorothea.txt
#   inflating: data/Albums/Evermore/evermore.txt
#   inflating: data/Albums/Evermore/goldrush.txt
#   inflating: data/Albums/Evermore/happiness.txt
#   inflating: data/Albums/Evermore/ivy.txt
#   inflating: data/Albums/Evermore/longstoryshort.txt
#   inflating: data/Albums/Evermore/marjorie.txt
#   inflating: data/Albums/Evermore/nobody_nocrime.txt
#   inflating: data/Albums/Evermore/tisthedamnseason.txt
#   inflating: data/Albums/Evermore/tolerateit.txt
#   inflating: data/Albums/Evermore/willow.txt
#   inflating: data/Albums/Fearless/Breathe.txt
#   inflating: data/Albums/Fearless/Change.txt
#   inflating: data/Albums/Fearless/Fearless.txt
#   inflating: data/Albums/Fearless/Fearless_LinerNotes_.txt
#   inflating: data/Albums/Fearless/Fifteen.txt
#   inflating: data/Albums/Fearless/Forever_Always.txt
#   inflating: data/Albums/Fearless/HeyStephen.txt
#   inflating: data/Albums/Fearless/LoveStory.txt
#   inflating: data/Albums/Fearless/TellMeWhy.txt
#   inflating: data/Albums/Fearless/TheBestDay.txt
#   inflating: data/Albums/Fearless/TheWayILovedYou.txt
#   inflating: data/Albums/Fearless/WhiteHorse.txt
#   inflating: data/Albums/Fearless/YouBelongWithMe.txt
#   inflating: data/Albums/Fearless/YoureNotSorry.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/Breathe.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/Change.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/ComeInWiththeRain.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/Fearless.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/Fifteen.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/Forever_Always.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/Forever_Always_PianoVersion_.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/HeyStephen.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/JumpThenFall.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/LoveStory.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/SuperStar.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/TellMeWhy.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/TheBestDay.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/TheOtherSideOfTheDoor.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/TheWayILovedYou.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/Untouchable.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/WhiteHorse.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/YouBelongWithMe.txt
#   inflating: data/Albums/Fearless_PlatinumEdition_/YoureNotSorry.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/Breathe_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/ByeByeBaby_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/Change_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/ComeInWithTheRain_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/DontYou_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/Fearless_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/Fifteen_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/Forever_Always_PianoVersion__TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/Forever_Always_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/HeyStephen_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/JumpThenFall_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/LoveStory_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/LoveStory_TaylorsVersion__ElviraRemix_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/Mr_PerfectlyFine_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/Superstar_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/TellMeWhy_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/ThatsWhen_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/TheBestDay_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/TheOtherSideoftheDoor_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/TheWayILovedYou_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/TodayWasaFairytale_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/Untouchable_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/WeWereHappy_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/WhiteHorse_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/YouAllOverMe_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/YouBelongWithMe_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion_/YoureNotSorry_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheFromtheVaultChapter/ByeByeBaby_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheFromtheVaultChapter/DontYou_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheFromtheVaultChapter/Mr_PerfectlyFine_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheFromtheVaultChapter/ThatsWhen_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheFromtheVaultChapter/WeWereHappy_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheFromtheVaultChapter/YouAllOverMe_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheHalfwayOuttheDoorChapter/Breathe_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheHalfwayOuttheDoorChapter/Forever_Always_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheHalfwayOuttheDoorChapter/Mr_PerfectlyFine_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheHalfwayOuttheDoorChapter/TheOtherSideoftheDoor_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheHalfwayOuttheDoorChapter/WhiteHorse_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheHalfwayOuttheDoorChapter/YoureNotSorry_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheIRememberWhatYouSaidLastNightChapter/Change_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheIRememberWhatYouSaidLastNightChapter/Fearless_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheIRememberWhatYouSaidLastNightChapter/Forever_Always_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheIRememberWhatYouSaidLastNightChapter/LoveStory_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheIRememberWhatYouSaidLastNightChapter/TellMeWhy_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheIRememberWhatYouSaidLastNightChapter/YouBelongWithMe_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheKissingInTheRainChapter/ComeInWithTheRain_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheKissingInTheRainChapter/Fifteen_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheKissingInTheRainChapter/HeyStephen_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheKissingInTheRainChapter/Superstar_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheKissingInTheRainChapter/TheWayILovedYou_TaylorsVersion_.txt
#   inflating: data/Albums/Fearless_TaylorsVersion__TheKissingInTheRainChapter/TodayWasaFairytale_TaylorsVersion_.txt
#   inflating: data/Albums/Folklore/august.txt
#   inflating: data/Albums/Folklore/betty.txt
#   inflating: data/Albums/Folklore/cardigan.txt
#   inflating: data/Albums/Folklore/epiphany.txt
#   inflating: data/Albums/Folklore/exile.txt
#   inflating: data/Albums/Folklore/hoax.txt
#   inflating: data/Albums/Folklore/illicitaffairs.txt
#   inflating: data/Albums/Folklore/invisiblestring.txt
#   inflating: data/Albums/Folklore/madwoman.txt
#   inflating: data/Albums/Folklore/mirrorball.txt
#   inflating: data/Albums/Folklore/mytearsricochet.txt
#   inflating: data/Albums/Folklore/peace.txt
#   inflating: data/Albums/Folklore/seven.txt
#   inflating: data/Albums/Folklore/the1.txt
#   inflating: data/Albums/Folklore/thelastgreatamericandynasty.txt
#   inflating: data/Albums/Folklore/thisismetrying.txt
#   inflating: data/Albums/LavenderHaze_Remixes_/LavenderHaze.txt
#   inflating: data/Albums/LavenderHaze_Remixes_/LavenderHaze_FelixJaehnRemix_.txt
#   inflating: data/Albums/LavenderHaze_Remixes_/LavenderHaze_JungleRemix_.txt
#   inflating: data/Albums/LavenderHaze_Remixes_/LavenderHaze_SnakehipsRemix_.txt
#   inflating: data/Albums/LavenderHaze_Remixes_/LavenderHaze_TensnakeRemix_.txt
#   inflating: data/Albums/Lover/Afterglow.txt
#   inflating: data/Albums/Lover/CorneliaStreet.txt
#   inflating: data/Albums/Lover/CruelSummer.txt
#   inflating: data/Albums/Lover/Daylight.txt
#   inflating: data/Albums/Lover/DeathbyaThousandCuts.txt
#   inflating: data/Albums/Lover/FalseGod.txt
#   inflating: data/Albums/Lover/IForgotThatYouExisted.txt
#   inflating: data/Albums/Lover/IThinkHeKnows.txt
#   inflating: data/Albums/Lover/ItsNicetoHaveaFriend.txt
#   inflating: data/Albums/Lover/LondonBoy.txt
#   inflating: data/Albums/Lover/Lover.txt
#   inflating: data/Albums/Lover/ME_.txt
#   inflating: data/Albums/Lover/MissAmericana_TheHeartbreakPrince.txt
#   inflating: data/Albums/Lover/PaperRings.txt
#   inflating: data/Albums/Lover/SoonYoullGetBetter.txt
#   inflating: data/Albums/Lover/TheArcher.txt
#   inflating: data/Albums/Lover/TheMan.txt
#   inflating: data/Albums/Lover/YouNeedToCalmDown.txt
#   inflating: data/Albums/Lover_LiveFromParis_HeartShapedVinyl/CorneliaStreet_LivefromParis_.txt
#   inflating: data/Albums/Lover_LiveFromParis_HeartShapedVinyl/Daylight_LivefromParis_.txt
#   inflating: data/Albums/Lover_LiveFromParis_HeartShapedVinyl/DeathbyaThousandCuts_LivefromParis_.txt
#   inflating: data/Albums/Lover_LiveFromParis_HeartShapedVinyl/Lover_LivefromParis_.txt
#   inflating: data/Albums/Lover_LiveFromParis_HeartShapedVinyl/ME__LivefromParis_.txt
#   inflating: data/Albums/Lover_LiveFromParis_HeartShapedVinyl/TheArcher_LivefromParis_.txt
#   inflating: data/Albums/Lover_LiveFromParis_HeartShapedVinyl/TheMan_LiveFromParis_.txt
#   inflating: data/Albums/Lover_LiveFromParis_HeartShapedVinyl/YouNeedToCalmDown_LivefromParis_.txt
#   inflating: data/Albums/MessageInABottle_FatMaxGRemix__TaylorsVersion_/MessageInABottle_TaylorsVersion__FatMaxGRemix_.txt
#   inflating: data/Albums/MessageInABottle_FatMaxGRemix__TaylorsVersion_/MessageInABottle_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Midnights/Anti_Hero.txt
#   inflating: data/Albums/Midnights/Bejeweled.txt
#   inflating: data/Albums/Midnights/Karma.txt
#   inflating: data/Albums/Midnights/Labyrinth.txt
#   inflating: data/Albums/Midnights/LavenderHaze.txt
#   inflating: data/Albums/Midnights/Maroon.txt
#   inflating: data/Albums/Midnights/Mastermind.txt
#   inflating: data/Albums/Midnights/MidnightRain.txt
#   inflating: data/Albums/Midnights/Question____.txt
#   inflating: data/Albums/Midnights/SnowOnTheBeach.txt
#   inflating: data/Albums/Midnights/SweetNothing.txt
#   inflating: data/Albums/Midnights/VigilanteShit.txt
#   inflating: data/Albums/Midnights/YoureOnYourOwn_Kid.txt
#   inflating: data/Albums/Midnights_3amEdition_/Anti_Hero.txt
#   inflating: data/Albums/Midnights_3amEdition_/Bejeweled.txt
#   inflating: data/Albums/Midnights_3amEdition_/BiggerThanTheWholeSky.txt
#   inflating: data/Albums/Midnights_3amEdition_/DearReader.txt
#   inflating: data/Albums/Midnights_3amEdition_/Glitch.txt
#   inflating: data/Albums/Midnights_3amEdition_/HighInfidelity.txt
#   inflating: data/Albums/Midnights_3amEdition_/Karma.txt
#   inflating: data/Albums/Midnights_3amEdition_/Labyrinth.txt
#   inflating: data/Albums/Midnights_3amEdition_/LavenderHaze.txt
#   inflating: data/Albums/Midnights_3amEdition_/Maroon.txt
#   inflating: data/Albums/Midnights_3amEdition_/Mastermind.txt
#   inflating: data/Albums/Midnights_3amEdition_/MidnightRain.txt
#   inflating: data/Albums/Midnights_3amEdition_/Paris.txt
#   inflating: data/Albums/Midnights_3amEdition_/Question____.txt
#   inflating: data/Albums/Midnights_3amEdition_/SnowOnTheBeach.txt
#   inflating: data/Albums/Midnights_3amEdition_/SweetNothing.txt
#   inflating: data/Albums/Midnights_3amEdition_/TheGreatWar.txt
#   inflating: data/Albums/Midnights_3amEdition_/VigilanteShit.txt
#   inflating: data/Albums/Midnights_3amEdition_/Wouldve_Couldve_Shouldve.txt
#   inflating: data/Albums/Midnights_3amEdition_/YoureOnYourOwn_Kid.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/Anti_Hero.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/Bejeweled.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/Karma.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/Labyrinth.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/LavenderHaze.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/Maroon.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/Mastermind.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/Meetmeatmidnight.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/MidnightRain.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/Question____.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/SnowOnTheBeach.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/SweetNothing.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/VigilanteShit.txt
#   inflating: data/Albums/Midnights_AppleMusicExclusive_/YoureOnYourOwn_Kid.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/Anti_Hero.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/Bejeweled.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/HitsDifferent.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/Karma.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/Labyrinth.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/LavenderHaze.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/Maroon.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/Mastermind.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/MidnightRain.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/Question____.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/SnowOnTheBeach.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/SweetNothing.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/SweetNothing_PianoRemix_.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/VigilanteShit.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/YoureOnYourOwn_Kid.txt
#   inflating: data/Albums/Midnights_TargetExclusive_/YoureOnYourOwn_Kid_StringsRemix_.txt
#   inflating: data/Albums/Midnights_TheLateNightEdition_/LavenderHaze.txt
#   inflating: data/Albums/Midnights_TheLateNightEdition_/Maroon.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Anti_Hero.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Bejeweled.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/BiggerThanTheWholeSky.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/DearReader.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Glitch.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/HighInfidelity.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/HitsDifferent.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Karma.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Karma_Remix_.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Labyrinth.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/LavenderHaze.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Maroon.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Mastermind.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/MidnightRain.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Paris.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Question____.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/SnowOnTheBeach.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/SnowOnTheBeach_feat_MoreLanaDelRey_.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/SweetNothing.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/TheGreatWar.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/VigilanteShit.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/Wouldve_Couldve_Shouldve.txt
#   inflating: data/Albums/Midnights_TheTillDawnEdition_/YoureOnYourOwn_Kid.txt
#   inflating: data/Albums/Red/22.txt
#   inflating: data/Albums/Red/AllTooWell.txt
#   inflating: data/Albums/Red/BeginAgain.txt
#   inflating: data/Albums/Red/ComeBack___BeHere.txt
#   inflating: data/Albums/Red/EverythingHasChanged.txt
#   inflating: data/Albums/Red/GirlatHome.txt
#   inflating: data/Albums/Red/HolyGround.txt
#   inflating: data/Albums/Red/IAlmostDo.txt
#   inflating: data/Albums/Red/IKnewYouWereTrouble.txt
#   inflating: data/Albums/Red/Red.txt
#   inflating: data/Albums/Red/SadBeautifulTragic.txt
#   inflating: data/Albums/Red/Starlight.txt
#   inflating: data/Albums/Red/StateofGrace.txt
#   inflating: data/Albums/Red/StayStayStay.txt
#   inflating: data/Albums/Red/TheLastTime.txt
#   inflating: data/Albums/Red/TheLuckyOne.txt
#   inflating: data/Albums/Red/TheMomentIKnew.txt
#   inflating: data/Albums/Red/Treacherous.txt
#   inflating: data/Albums/Red/WeAreNeverEverGettingBackTogether.txt
#   inflating: data/Albums/Red_TaylorsVersion_/22_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/AMessageFromTaylor.txt
#   inflating: data/Albums/Red_TaylorsVersion_/AllTooWell_10MinuteVersion__TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/AllTooWell_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/Babe_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/BeginAgain_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/BetterMan_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/ComeBack___BeHere_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/EverythingHasChanged_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/ForeverWinter_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/GirlAtHome_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/HolyGround_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/IAlmostDo_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/IBetYouThinkAboutMe_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/IKnewYouWereTrouble_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/MessageInABottle_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/NothingNew_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/Red_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/Ronan_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/Run_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/SadBeautifulTragic_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/Starlight_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/StateOfGrace_AcousticVersion__TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/StateofGrace_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/StayStayStay_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/TheLastTime_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/TheLuckyOne_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/TheMomentIKnew_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/TheVeryFirstNight_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/Treacherous_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion_/WeAreNeverEverGettingBackTogether_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__CouldYouBeTheOneChapter/BeginAgain_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__CouldYouBeTheOneChapter/EverythingHasChanged_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__CouldYouBeTheOneChapter/MessageInABottle_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion__CouldYouBeTheOneChapter/Starlight_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__CouldYouBeTheOneChapter/StateofGrace_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__CouldYouBeTheOneChapter/Treacherous_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__FromTheVaultChapter/Babe_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion__FromTheVaultChapter/BetterMan_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion__FromTheVaultChapter/ForeverWinter_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion__FromTheVaultChapter/NothingNew_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion__FromTheVaultChapter/Run_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion__FromTheVaultChapter/TheVeryFirstNight_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion__SheWroteASongAboutMeChapter/IAlmostDo_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__SheWroteASongAboutMeChapter/IBetYouThinkAboutMe_TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion__SheWroteASongAboutMeChapter/IKnewYouWereTrouble_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__SheWroteASongAboutMeChapter/Red_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__SheWroteASongAboutMeChapter/TheLuckyOne_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__SheWroteASongAboutMeChapter/WeAreNeverEverGettingBackTogether_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__TheSlowMotionChapter/AllTooWell_10MinuteVersion__TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/Red_TaylorsVersion__TheSlowMotionChapter/ComeBack___BeHere_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__TheSlowMotionChapter/HolyGround_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__TheSlowMotionChapter/SadBeautifulTragic_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__TheSlowMotionChapter/TheLastTime_TaylorsVersion_.txt
#   inflating: data/Albums/Red_TaylorsVersion__TheSlowMotionChapter/TheMomentIKnew_TaylorsVersion_.txt
#   inflating: data/Albums/Reputation/CallItWhatYouWant.txt
#   inflating: data/Albums/Reputation/DancingWithOurHandsTied.txt
#   inflating: data/Albums/Reputation/Delicate.txt
#   inflating: data/Albums/Reputation/DontBlameMe.txt
#   inflating: data/Albums/Reputation/Dress.txt
#   inflating: data/Albums/Reputation/EndGame.txt
#   inflating: data/Albums/Reputation/GetawayCar.txt
#   inflating: data/Albums/Reputation/Gorgeous.txt
#   inflating: data/Albums/Reputation/IDidSomethingBad.txt
#   inflating: data/Albums/Reputation/IfYoureAnythingLikeMe_Poem_.txt
#   inflating: data/Albums/Reputation/KingofMyHeart.txt
#   inflating: data/Albums/Reputation/LookWhatYouMadeMeDo.txt
#   inflating: data/Albums/Reputation/NewYearsDay.txt
#   inflating: data/Albums/Reputation/ReputationMagazineVol_1.txt
#   inflating: data/Albums/Reputation/Reputation_Prologue_.txt
#   inflating: data/Albums/Reputation/SoItGoes___.txt
#   inflating: data/Albums/Reputation/ThisIsWhyWeCantHaveNiceThings.txt
#   inflating: data/Albums/Reputation/WhySheDisappeared_Poem_.txt
#   inflating: data/Albums/Reputation/___ReadyforIt_.txt
#   inflating: data/Albums/SpeakNow/BacktoDecember.txt
#   inflating: data/Albums/SpeakNow/BetterThanRevenge.txt
#   inflating: data/Albums/SpeakNow/DearJohn.txt
#   inflating: data/Albums/SpeakNow/Enchanted.txt
#   inflating: data/Albums/SpeakNow/Haunted.txt
#   inflating: data/Albums/SpeakNow/Innocent.txt
#   inflating: data/Albums/SpeakNow/LastKiss.txt
#   inflating: data/Albums/SpeakNow/LongLive.txt
#   inflating: data/Albums/SpeakNow/Mean.txt
#   inflating: data/Albums/SpeakNow/Mine.txt
#   inflating: data/Albums/SpeakNow/NeverGrowUp.txt
#   inflating: data/Albums/SpeakNow/SparksFly.txt
#   inflating: data/Albums/SpeakNow/SpeakNow.txt
#   inflating: data/Albums/SpeakNow/TheStoryOfUs.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/BackToDecember_Acoustic_.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/BacktoDecember.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/BetterThanRevenge.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/DearJohn.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/Enchanted.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/Haunted.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/Haunted_AcousticVersion_.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/IfThisWasaMovie.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/Innocent.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/LastKiss.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/LongLive.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/Mean.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/Mine.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/Mine_PopMix_.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/NeverGrowUp.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/Ours.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/SparksFly.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/SpeakNow.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/Superman.txt
#   inflating: data/Albums/SpeakNow_Deluxe_/TheStoryOfUs.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/BackToDecember_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/BetterThanRevenge_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/CastlesCrumbling_TaylorsVersion__FromTheVault_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/DearJohn_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/ElectricTouch_TaylorsVersion__FromTheVault_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/Enchanted_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/FoolishOne_TaylorsVersion__FromTheVault_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/Haunted_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/ICanSeeYou_TaylorsVersion__FromTheVault_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/Innocent_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/LastKiss_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/LongLive_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/Mean_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/Mine_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/NeverGrowUp_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/Ours_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/SparksFly_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/SpeakNow_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/Superman_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/TheStoryofUs_TaylorsVersion_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/Timeless_TaylorsVersion__FromTheVault_.txt
#   inflating: data/Albums/SpeakNow_TaylorsVersion_/WhenEmmaFallsinLove_TaylorsVersion__FromTheVault_.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/AtNight.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/DoppelGospel.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/DumpsterDiving.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/GetEm.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/HappyFace.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/LikeWhatLikeMe.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/Lush.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/Nexium.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/NyBushmen.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/PackKevorkian.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/Rap_Unemployment.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/Suppository.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/TheGods.txt
#   inflating: data/Albums/SpeakNow_WorldTourLive/WenchRench.txt
#   inflating: data/Albums/TaylorSwift/APerfectlyGoodHeart.txt
#   inflating: data/Albums/TaylorSwift/APlaceInThisWorld.txt
#   inflating: data/Albums/TaylorSwift/ColdasYou.txt
#   inflating: data/Albums/TaylorSwift/ImOnlyMeWhenImWithYou.txt
#   inflating: data/Albums/TaylorSwift/Invisible.txt
#   inflating: data/Albums/TaylorSwift/MarysSong_OhMyMyMy_.txt
#   inflating: data/Albums/TaylorSwift/OurSong.txt
#   inflating: data/Albums/TaylorSwift/PicturetoBurn.txt
#   inflating: data/Albums/TaylorSwift/ShouldveSaidNo.txt
#   inflating: data/Albums/TaylorSwift/StayBeautiful.txt
#   inflating: data/Albums/TaylorSwift/TaylorSwift_LinerNotes_.txt
#   inflating: data/Albums/TaylorSwift/TeardropsOnMyGuitar.txt
#   inflating: data/Albums/TaylorSwift/TeardropsonMyGuitar_PopVersion_.txt
#   inflating: data/Albums/TaylorSwift/TheOutside.txt
#   inflating: data/Albums/TaylorSwift/TiedTogetherwithaSmile.txt
#   inflating: data/Albums/TaylorSwift/TimMcGraw.txt
#   inflating: data/Albums/TheMoreFearless_TaylorsVersion_Chapter/Fearless_TaylorsVersion_.txt
#   inflating: data/Albums/TheMoreFearless_TaylorsVersion_Chapter/IfThisWasaMovie_TaylorsVersion_.txt
#   inflating: data/Albums/TheMoreFearless_TaylorsVersion_Chapter/LoveStory_TaylorsVersion_.txt
#   inflating: data/Albums/TheMoreFearless_TaylorsVersion_Chapter/WhiteHorse_TaylorsVersion_.txt
#   inflating: data/Albums/TheMoreFearless_TaylorsVersion_Chapter/YouBelongWithMe_TaylorsVersion_.txt
#   inflating: data/Albums/TheMoreLoverChapter/AllOfTheGirlsYouLovedBefore.txt
#   inflating: data/Albums/TheMoreLoverChapter/CruelSummer.txt
#   inflating: data/Albums/TheMoreLoverChapter/Lover.txt
#   inflating: data/Albums/TheMoreLoverChapter/TheArcher.txt
#   inflating: data/Albums/TheMoreLoverChapter/TheMan.txt
#   inflating: data/Albums/TheMoreRed_TaylorsVersion_Chapter/22_TaylorsVersion_.txt
#   inflating: data/Albums/TheMoreRed_TaylorsVersion_Chapter/AllTooWell_10MinuteVersion__TaylorsVersion__FromtheVault_.txt
#   inflating: data/Albums/TheMoreRed_TaylorsVersion_Chapter/EyesOpen_TaylorsVersion_.txt
#   inflating: data/Albums/TheMoreRed_TaylorsVersion_Chapter/IKnewYouWereTrouble_TaylorsVersion_.txt
#   inflating: data/Albums/TheMoreRed_TaylorsVersion_Chapter/Safe_Sound_TaylorsVersion_.txt
#   inflating: data/Albums/TheMoreRed_TaylorsVersion_Chapter/WeAreNeverEverGettingBackTogether_TaylorsVersion_.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/champagneproblems.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/closure.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/coneyisland.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/cowboylikeme.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/dorothea.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/evermore.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/goldrush.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/happiness.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/itstimetogo.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/ivy.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/longstoryshort.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/marjorie.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/nobody_nocrime.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/rightwhereyouleftme.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/tisthedamnseason.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/tolerateit.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/willow.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/willow_dancingwitchversion__ElviraRemix_.txt
#   inflating: data/Albums/evermore_JapaneseEdition_/willow_lonelywitchversion_.txt
#   inflating: data/Albums/evermore_deluxeversion_/Evermore_LinerNotes_.txt
#   inflating: data/Albums/evermore_deluxeversion_/champagneproblems.txt
#   inflating: data/Albums/evermore_deluxeversion_/closure.txt
#   inflating: data/Albums/evermore_deluxeversion_/coneyisland.txt
#   inflating: data/Albums/evermore_deluxeversion_/cowboylikeme.txt
#   inflating: data/Albums/evermore_deluxeversion_/dorothea.txt
#   inflating: data/Albums/evermore_deluxeversion_/evermore.txt
#   inflating: data/Albums/evermore_deluxeversion_/goldrush.txt
#   inflating: data/Albums/evermore_deluxeversion_/happiness.txt
#   inflating: data/Albums/evermore_deluxeversion_/itstimetogo.txt
#   inflating: data/Albums/evermore_deluxeversion_/ivy.txt
#   inflating: data/Albums/evermore_deluxeversion_/longstoryshort.txt
#   inflating: data/Albums/evermore_deluxeversion_/marjorie.txt
#   inflating: data/Albums/evermore_deluxeversion_/nobody_nocrime.txt
#   inflating: data/Albums/evermore_deluxeversion_/rightwhereyouleftme.txt
#   inflating: data/Albums/evermore_deluxeversion_/tisthedamnseason.txt
#   inflating: data/Albums/evermore_deluxeversion_/tolerateit.txt
#   inflating: data/Albums/evermore_deluxeversion_/willow.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/champagneproblems.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/closure.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/coneyisland.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/cowboylikeme.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/dorothea.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/evermore.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/goldrush.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/happiness.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/itstimetogo.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/ivy.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/longstoryshort.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/marjorie.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/nobody_nocrime.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/rightwhereyouleftme.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/tisthedamnseason.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/tolerateit.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/willow.txt
#   inflating: data/Albums/evermore_digitallyautographedfanedition_/willow_90_strendremix_.txt
#   inflating: data/Albums/evermore_thedroppedyourhandwhiledancingchapter/champagneproblems.txt
#   inflating: data/Albums/evermore_thedroppedyourhandwhiledancingchapter/coneyisland.txt
#   inflating: data/Albums/evermore_thedroppedyourhandwhiledancingchapter/happiness.txt
#   inflating: data/Albums/evermore_thedroppedyourhandwhiledancingchapter/hoax.txt
#   inflating: data/Albums/evermore_thedroppedyourhandwhiledancingchapter/itstimetogo.txt
#   inflating: data/Albums/evermore_thedroppedyourhandwhiledancingchapter/tolerateit.txt
#   inflating: data/Albums/evermore_theforeveristhesweetestconchapter/cowboylikeme.txt
#   inflating: data/Albums/evermore_theforeveristhesweetestconchapter/evermore.txt
#   inflating: data/Albums/evermore_theforeveristhesweetestconchapter/invisiblestring.txt
#   inflating: data/Albums/evermore_theforeveristhesweetestconchapter/longstoryshort.txt
#   inflating: data/Albums/evermore_theforeveristhesweetestconchapter/mirrorball.txt
#   inflating: data/Albums/evermore_theforeveristhesweetestconchapter/willow.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/august_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/betty_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/cardigan_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/epiphany_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/exile_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/hoax_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/illicitaffairs_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/invisiblestring_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/madwoman_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/mirrorball_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/mytearsricochet_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/peace_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/seven_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/the1_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/thelakes_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/thelastgreatamericandynasty_thelongpondstudiosessions_.txt
#   inflating: data/Albums/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_/thisismetrying_thelongpondstudiosessions_.txt
#   inflating: data/Albums/theladieslunchingchapter/august.txt
#   inflating: data/Albums/theladieslunchingchapter/betty.txt
#   inflating: data/Albums/theladieslunchingchapter/dorothea.txt
#   inflating: data/Albums/theladieslunchingchapter/marjorie.txt
#   inflating: data/Albums/theladieslunchingchapter/nobody_nocrime.txt
#   inflating: data/Albums/theladieslunchingchapter/rightwhereyouleftme.txt
#   inflating: data/Albums/thelakes_7_Single_RecordStoreDayExclusive_/thelakes.txt
#   inflating: data/Albums/thelakes_7_Single_RecordStoreDayExclusive_/thelakes_originalversion_.txt
#   inflating: data/Cover_Art/1989.jpg
#   inflating: data/Cover_Art/AllTooWell_10MinuteVersion__TheShortFilm__EP.jpg
#   inflating: data/Cover_Art/Anti_Hero_Remixes_.jpg
#   inflating: data/Cover_Art/Carolina_FromTheMotionPicture_WhereTheCrawdadsSing__.jpg
#   inflating: data/Cover_Art/Evermore.jpg
#   inflating: data/Cover_Art/Fearless_PlatinumEdition_.jpg
#   inflating: data/Cover_Art/Fearless_Taylor_sVersion_.jpg
#   inflating: data/Cover_Art/Fearless_Taylor_sVersion__TheFromtheVaultChapter.jpg
#   inflating: data/Cover_Art/Fearless_Taylor_sVersion__TheHalfwayOuttheDoorChapter.jpg
#   inflating: data/Cover_Art/Fearless_Taylor_sVersion__TheIRememberWhatYouSaidLastNightChapter.jpg
#   inflating: data/Cover_Art/Fearless_Taylor_sVersion__TheKissingInTheRainChapter.jpg
#   inflating: data/Cover_Art/Folklore.jpg
#   inflating: data/Cover_Art/LavenderHaze_Remixes_.jpg
#   inflating: data/Cover_Art/Lover.jpg
#   inflating: data/Cover_Art/Lover_LiveFromParis_HeartShapedVinyl.jpg
#   inflating: data/Cover_Art/MessageInABottle_FatMaxGRemix__Taylor_sVersion_.jpg
#   inflating: data/Cover_Art/Midnights.jpg
#   inflating: data/Cover_Art/Midnights_3amEdition_.jpg
#   inflating: data/Cover_Art/Midnights_AppleMusicExclusive_.jpg
#   inflating: data/Cover_Art/Midnights_TargetExclusive_.jpg
#   inflating: data/Cover_Art/Midnights_TheLateNightEdition_.jpg
#   inflating: data/Cover_Art/Midnights_TheTilDawnEdition_.jpg
#   inflating: data/Cover_Art/Midnights_TheTillDawnEdition_.jpg
#   inflating: data/Cover_Art/Red.jpg
#   inflating: data/Cover_Art/Red_Taylor_sVersion_.jpg
#   inflating: data/Cover_Art/Red_Taylor_sVersion__CouldYouBeTheOneChapter.jpg
#   inflating: data/Cover_Art/Red_Taylor_sVersion__FromTheVaultChapter.jpg
#   inflating: data/Cover_Art/Red_Taylor_sVersion__SheWroteASongAboutMeChapter.jpg
#   inflating: data/Cover_Art/Red_Taylor_sVersion__TheSlowMotionChapter.jpg
#   inflating: data/Cover_Art/Reputation.jpg
#   inflating: data/Cover_Art/SpeakNow.jpg
#   inflating: data/Cover_Art/SpeakNow_Deluxe_.jpg
#   inflating: data/Cover_Art/SpeakNow_Taylor_sVersion_.jpg
#   inflating: data/Cover_Art/SpeakNow_WorldTourLive.jpg
#   inflating: data/Cover_Art/TaylorSwift.jpg
#   inflating: data/Cover_Art/TheMoreFearless_Taylor_sVersion_Chapter.jpg
#   inflating: data/Cover_Art/TheMoreLoverChapter.jpg
#   inflating: data/Cover_Art/TheMoreRed_Taylor_sVersion_Chapter.jpg
#   inflating: data/Cover_Art/evermore_JapaneseEdition_.jpg
#   inflating: data/Cover_Art/evermore_deluxeversion_.jpg
#   inflating: data/Cover_Art/evermore_digitallyautographedfanedition_.jpg
#   inflating: data/Cover_Art/evermore_the_foreveristhesweetestcon_chapter.jpg
#   inflating: data/Cover_Art/evermore_thedroppedyourhandwhiledancingchapter.jpg
#   inflating: data/Cover_Art/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_.jpg
#   inflating: data/Cover_Art/the_ladieslunching_chapter.jpg
#   inflating: data/Cover_Art/thelakes_7_Single_RecordStoreDayExclusive_.jpg
#   inflating: data/Tabular/1989.csv
#   inflating: data/Tabular/AllTooWell_10MinuteVersion__TheShortFilm__EP.csv
#   inflating: data/Tabular/Anti_Hero_Remixes_.csv
#   inflating: data/Tabular/Carolina_FromTheMotionPicture_WhereTheCrawdadsSing__.csv
#   inflating: data/Tabular/Evermore.csv
#   inflating: data/Tabular/Fearless_PlatinumEdition_.csv
#   inflating: data/Tabular/Fearless_Taylor_sVersion_.csv
#   inflating: data/Tabular/Fearless_Taylor_sVersion__TheFromtheVaultChapter.csv
#   inflating: data/Tabular/Fearless_Taylor_sVersion__TheHalfwayOuttheDoorChapter.csv
#   inflating: data/Tabular/Fearless_Taylor_sVersion__TheIRememberWhatYouSaidLastNightChapter.csv
#   inflating: data/Tabular/Fearless_Taylor_sVersion__TheKissingInTheRainChapter.csv
#   inflating: data/Tabular/Folklore.csv
#   inflating: data/Tabular/LavenderHaze_Remixes_.csv
#   inflating: data/Tabular/Lover.csv
#   inflating: data/Tabular/Lover_LiveFromParis_HeartShapedVinyl.csv
#   inflating: data/Tabular/MessageInABottle_FatMaxGRemix__Taylor_sVersion_.csv
#   inflating: data/Tabular/Midnights.csv
#   inflating: data/Tabular/Midnights_3amEdition_.csv
#   inflating: data/Tabular/Midnights_AppleMusicExclusive_.csv
#   inflating: data/Tabular/Midnights_TargetExclusive_.csv
#   inflating: data/Tabular/Midnights_TheLateNightEdition_.csv
#   inflating: data/Tabular/Midnights_TheTilDawnEdition_.csv
#   inflating: data/Tabular/Midnights_TheTillDawnEdition_.csv
#   inflating: data/Tabular/Red.csv
#   inflating: data/Tabular/Red_Taylor_sVersion_.csv
#   inflating: data/Tabular/Red_Taylor_sVersion__CouldYouBeTheOneChapter.csv
#   inflating: data/Tabular/Red_Taylor_sVersion__FromTheVaultChapter.csv
#   inflating: data/Tabular/Red_Taylor_sVersion__SheWroteASongAboutMeChapter.csv
#   inflating: data/Tabular/Red_Taylor_sVersion__TheSlowMotionChapter.csv
#   inflating: data/Tabular/Reputation.csv
#   inflating: data/Tabular/SpeakNow.csv
#   inflating: data/Tabular/SpeakNow_Deluxe_.csv
#   inflating: data/Tabular/SpeakNow_Taylor_sVersion_.csv
#   inflating: data/Tabular/SpeakNow_WorldTourLive.csv
#   inflating: data/Tabular/TaylorSwift.csv
#   inflating: data/Tabular/TheMoreFearless_Taylor_sVersion_Chapter.csv
#   inflating: data/Tabular/TheMoreLoverChapter.csv
#   inflating: data/Tabular/TheMoreRed_Taylor_sVersion_Chapter.csv
#   inflating: data/Tabular/evermore_JapaneseEdition_.csv
#   inflating: data/Tabular/evermore_deluxeversion_.csv
#   inflating: data/Tabular/evermore_digitallyautographedfanedition_.csv
#   inflating: data/Tabular/evermore_the_foreveristhesweetestcon_chapter.csv
#   inflating: data/Tabular/evermore_thedroppedyourhandwhiledancingchapter.csv
#   inflating: data/Tabular/folklore_thelongpondstudiosessions_RecordStoreDayExclusive_.csv
#   inflating: data/Tabular/the_ladieslunching_chapter.csv
#   inflating: data/Tabular/thelakes_7_Single_RecordStoreDayExclusive_.csv

# %% [markdown]
# # 1. Install Dependencies

# %%
# !pip install loguru
# !pip install transformers==4.30
# !pip install -q -U trl accelerate git+https://github.com/huggingface/peft.git
# !pip install -q datasets bitsandbytes einops wandb
# !pip install diffusers==0.20.2
# Out:
# Collecting loguru
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: loguru
# Successfully installed loguru-0.7.2
# Collecting transformers==4.30
#   Downloading transformers-4.30.0-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 35.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers==4.30)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 73.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers==4.30)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.18.0 safetensors-0.4.0 tokenizers-0.13.3 transformers-4.30.0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.2 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 14.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.2 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done
# Collecting diffusers==0.20.2
#   Downloading diffusers-0.20.2.tar.gz (989 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.1/989.1 kB 6.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.20.2) (6.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers==0.20.2) (3.12.4)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.20.2) (0.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers==0.20.2) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.20.2) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers==0.20.2) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers==0.20.2) (0.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.20.2) (9.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.20.2) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.20.2) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.20.2) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.20.2) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.20.2) (23.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.20.2) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.20.2) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.20.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.20.2) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers==0.20.2) (2023.7.22)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.20.2-py3-none-any.whl size=1342633 sha256=278a039fbd05c151523710106c8c0847784b60161505268bc00ae88a25c698fd
#   Stored in directory: /root/.cache/pip/wheels/dc/8b/d9/34f7a1936109e05e9bba0cc2241a6f8cd89e25959dc7aae942
# Successfully built diffusers
# Installing collected packages: diffusers
# Successfully installed diffusers-0.20.2

# %% [markdown]
# # 2. Import Working Libraries

# %%
import os
import re
import pandas as pd
from nltk import word_tokenize
from loguru import logger
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
from huggingface_hub import notebook_login
from datasets import load_dataset

# %% [markdown]
# # 3. Huggingface Login

# %% [markdown]
# To use certain versions of Llama 2, one needs to be granted access through the Huggingface API Token. Therefore, one should login from an account authorized to access them, through running the following cell:

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# # 4. Utils

# %% [markdown]
# This module contains specific methods that will be useful later on.

# %%
def flatten_list(list_of_lists):
    flattened_list = []
    for sublist in list_of_lists:
        flattened_list.extend(sublist)
    return flattened_list

# %% [markdown]
# # 5. Loading Data

# %%
class OriginalDatasetLoader():
    def __init__(
            self,
            data_raw_dir: str="data",
            albums_dir: str="Albums"
    ):
        self.albums_dir = os.path.join(data_raw_dir, albums_dir)
        self.songs_dict = {}
        self.songs_df = pd.DataFrame()

    def _read_txt(self, data_dir: str, data_file_name: str):
        with open(os.path.join(data_dir, data_file_name), "r") as txt_file:
            file_content = txt_file.read()

        return file_content

    def _get_album_dir(self, album: str):
        return os.path.join(self.albums_dir, album)

    def _get_albums_list(self):
        return os.listdir(self.albums_dir)

    def _get_album_songs_list(self, album_dir: str):
        return os.listdir(album_dir)

    def _set_songs_dict(self):
        for album in self._get_albums_list():
            album_dir = self._get_album_dir(album)
            song_titles_list = self._get_album_songs_list(album_dir)
            self.songs_dict[album] = {song_title[0:-4]: self._read_txt(album_dir, song_title) for song_title in song_titles_list}

    def get_songs_dict(self):
        self._set_songs_dict()
        return self.songs_dict

    def _set_songs_df(self):
        for album in self._get_albums_list():
            album_dir = self._get_album_dir(album)
            song_titles_list = self._get_album_songs_list(album_dir)
            curr_album_df = pd.DataFrame.from_dict({"title": [song_title[0:-4] for song_title in song_titles_list], "lyrics": [self._read_txt(album_dir, song_title) for song_title in song_titles_list], "album": [album for _ in range(len(song_titles_list))]})
            if self.songs_df is pd.DataFrame.empty:
                self.songs_df = curr_album_df
            else:
                self.songs_df = pd.concat([self.songs_df, curr_album_df], axis=0)

        self.songs_df.reset_index(inplace=True, drop=True)

    def get_songs_df(self):
        self._set_songs_df()
        return self.songs_df

# %%
lyrics_dataset_generator = OriginalDatasetLoader()
songs_df = lyrics_dataset_generator.get_songs_df()
songs_df.head()
# Out:
#                                           title  \
# 0                       Breathe_TaylorsVersion_
# 1                       Fifteen_TaylorsVersion_
# 2  Forever_Always_PianoVersion__TaylorsVersion_
# 3     WeWereHappy_TaylorsVersion__FromtheVault_
# 4                      Fearless_TaylorsVersion_
#
#                                               lyrics                     album
# 0  33 ContributorsTranslationsTürkçeEspañolСрпски...  Fearless_TaylorsVersion_
# 1  51 ContributorsTranslationsTürkçeEspañolСрпски...  Fearless_TaylorsVersion_
# 2  27 ContributorsTranslationsTürkçeСрпскиPortugu...  Fearless_TaylorsVersion_
# 3  72 ContributorsTranslationsTürkçeEspañolСрпски...  Fearless_TaylorsVersion_
# 4  42 ContributorsTranslationsTürkçeEspañolСрпски...  Fearless_TaylorsVersion_

# %% [markdown]
# # 6. Parsing and Preprocessing

# %%
class Parser():
    def __init__(
        self,
        lyrics_dataset: pd.DataFrame,
        delimitation_pattern: str=r"Lyrics([\s\S]*?)Embed"
    ):
        self.dataset = lyrics_dataset
        self.delimitation_pattern = delimitation_pattern

    def _get_clean_content(self, input_string: str):
        match = re.search(self.delimitation_pattern, input_string)
        lyrics_content = match.group(1)
        return lyrics_content

    def _remove_end_digits(self, input_string: str):
        return re.sub(r'\d+$', '', input_string)

    def remove_irrelevant_content(self):
        self.dataset.lyrics = self.dataset.lyrics.apply(self._get_clean_content)
        self.dataset.lyrics = self.dataset.lyrics.apply(self._remove_end_digits)

    def parse_data(self):
        self.remove_irrelevant_content()

    def get_parsed_data(self):
        self.parse_data()
        return self.dataset

# %%
parser = Parser(songs_df)
parsed_data = parser.get_parsed_data()
parsed_data.head()
# Out:
#                                           title  \
# 0                       Breathe_TaylorsVersion_
# 1                       Fifteen_TaylorsVersion_
# 2  Forever_Always_PianoVersion__TaylorsVersion_
# 3     WeWereHappy_TaylorsVersion__FromtheVault_
# 4                      Fearless_TaylorsVersion_
#
#                                               lyrics                     album
# 0  [Verse 1: Taylor Swift]\nI see your face in my...  Fearless_TaylorsVersion_
# 1  [Verse 1]\nYou take a deep breath and you walk...  Fearless_TaylorsVersion_
# 2  [Verse 1]\nOnce upon a time\nI believe it was ...  Fearless_TaylorsVersion_
# 3  [Verse 1]\nWe used to walk along the streets\n...  Fearless_TaylorsVersion_
# 4  [Verse 1]\nThere's something 'bout the way\nTh...  Fearless_TaylorsVersion_

# %%
class PreProcessor():
    def __init__(
        self,
        lyrics_dataset: pd.DataFrame,
    ):
        self.dataset = lyrics_dataset

    def _remove_structure_markers(self, input_string: str):
        return re.sub(r'\[[^\]]*\]\n', '', input_string)

    def _remove_special_characters(self, input_string: str):
        return re.sub(r'[^a-zA-Z0-9\s]', '', input_string)

    def _lowercase_text(self, input_string: str):
        return input_string.lower()

    def _remove_new_line_characters(self, input_string: str):
        return input_string.replace("\n", " ")

    def _remove_horizontal_tabs(self, input_string: str):
        return input_string.replace("\t", " ")

    def _remove_specific_characters(self, input_string: str):
        new_string = input_string.replace("\u205f", " ")
        return new_string.replace("\u2005", " ")

    def drop_empty_entries(self):
        self.dataset = self.dataset.loc[self.dataset["lyrics"] != ''].reset_index(drop=True)
        self.dataset = self.dataset.loc[self.dataset["lyrics"] != ' '].reset_index(drop=True)

    def drop_duplicated_songs(self):
        self.dataset.drop_duplicates(subset='lyrics', keep='first', inplace=True)
        self.dataset.reset_index(inplace=True, drop=True)

        # TODO: Check whether we should drop title duplicates too

    def remove_noise(self):
        self.dataset.lyrics = self.dataset.lyrics.apply(self._remove_structure_markers)
        self.dataset.lyrics = self.dataset.lyrics.apply(self._remove_special_characters)
        self.dataset.lyrics = self.dataset.lyrics.apply(self._remove_specific_characters)

    def standardize_text(self, keep_new_lines):
        self.dataset.lyrics = self.dataset.lyrics.apply(self._lowercase_text)
        self.dataset.lyrics = self.dataset.lyrics.apply(self._remove_horizontal_tabs)
        if keep_new_lines:
          self.dataset.lyrics = self.dataset.lyrics.apply(self._remove_new_line_characters)

    def preprocess_data(self, keep_new_lines):
        # Remove Noisy Info
        self.remove_noise()

        # Drop Duplicates
        self.drop_duplicated_songs()

        # Drop Empty Entries
        self.drop_empty_entries()

        # Normalize
        self.standardize_text(keep_new_lines)

    def get_preprocessed_data(self, keep_new_lines=False):
        self.preprocess_data(keep_new_lines)
        return self.dataset

# %%
preprocessor = PreProcessor(parsed_data)
preprocessed_data = preprocessor.get_preprocessed_data()
preprocessed_data.head()
# Out:
#                                           title  \
# 0                       Breathe_TaylorsVersion_
# 1                       Fifteen_TaylorsVersion_
# 2  Forever_Always_PianoVersion__TaylorsVersion_
# 3     WeWereHappy_TaylorsVersion__FromtheVault_
# 4                      Fearless_TaylorsVersion_
#
#                                               lyrics                     album
# 0  i see your face in my mind as i drive away\nca...  Fearless_TaylorsVersion_
# 1  you take a deep breath and you walk through th...  Fearless_TaylorsVersion_
# 2  once upon a time\ni believe it was a tuesday w...  Fearless_TaylorsVersion_
# 3  we used to walk along the streets\nwhen the po...  Fearless_TaylorsVersion_
# 4  theres something bout the way\nthe street look...  Fearless_TaylorsVersion_

# %% [markdown]
# # 7. Splitting Data

# %%
class Splitter():
    def __init__(
            self,
            test_album_name: str = "Lover"
    ):
        self.test_album = test_album_name

    def train_test_split(self, dataset: pd.DataFrame):
        test_df = dataset.loc[dataset.album == self.test_album].reset_index(drop=True)
        train_df = dataset.loc[dataset.album != self.test_album].reset_index(drop=True)

        return train_df, test_df

# %%
splitter = Splitter()
train_dataset, test_dataset = splitter.train_test_split(preprocessed_data)
logger.info(train_dataset.head())
logger.info(test_dataset.head())
# Out:
# 2023-10-10 20:21:24.891 | INFO     | __main__:<cell line: 3>:3 -                                           title  \
# 0                       Breathe_TaylorsVersion_
# 1                       Fifteen_TaylorsVersion_
# 2  Forever_Always_PianoVersion__TaylorsVersion_
# 3     WeWereHappy_TaylorsVersion__FromtheVault_
# 4                      Fearless_TaylorsVersion_
#
#                                               lyrics                     album
# 0  i see your face in my mind as i drive away\nca...  Fearless_TaylorsVersion_
# 1  you take a deep breath and you walk through th...  Fearless_TaylorsVersion_
# 2  once upon a time\ni believe it was a tuesday w...  Fearless_TaylorsVersion_
# 3  we used to walk along the streets\nwhen the po...  Fearless_TaylorsVersion_
# 4  theres something bout the way\nthe street look...  Fearless_TaylorsVersion_
# 2023-10-10 20:21:24.898 | INFO     | __main__:<cell line: 4>:4 -                    title                                             lyrics  \
# 0  IForgotThatYouExisted  how many days did i spend thinking\nbout how y...
# 1              Afterglow  i blew things out of proportion now youre blue...
# 2     SoonYoullGetBetter  the buttons of my coat were tangled in my hair...
# 3             PaperRings  the moon is high\nlike your friends were the n...
# 4   ItsNicetoHaveaFriend  ooh\nooh\n\nschool bell rings walk me home\nsi...
#
#    album
# 0  Lover
# 1  Lover
# 2  Lover
# 3  Lover
# 4  Lover

# %% [markdown]
# # 8. Lyrics Generators

# %% [markdown]
# ## 8.1. Solution 1: Training an LSTM from scratch

# %% [markdown]
# ### 8.1.1. Generating Text Generation Samples

# %%
class TextGenerationSamplesGenerator():
    def __init__(
            self,
            vocab_path: str = None,
            padding_token: str = "[PAD]",
            bos_token: str = "[BOS]",
            eos_token: str = "[EOS]",
            unk_token: str = "[UNK]"
    ):
        self.vocab_path = vocab_path
        self.padding_token = padding_token
        self.bos_token = bos_token
        self.eos_token = eos_token
        self.unk_token = unk_token

    def _tokenize_text(self, input_string: str):
        return input_string.split(" ")

    def tokenize_lyrics(self, dataset: pd.DataFrame):
        return dataset.lyrics.apply(self._tokenize_text)

    def _get_unique_tokens(self, lyrics_list: pd.Series):
        all_tokens = flatten_list(lyrics_list)
        logger.info(f"Number of words in the dataset: {len(all_tokens)}")
        return sorted(list(set(all_tokens)))

    def _add_bos_eos_tokens(self, token_list: list):
        token_list.insert(0, self.bos_token)
        token_list.append(self.eos_token)
        return token_list

    def _add_special_tokens(self, token_list: list):
        token_list = self._add_bos_eos_tokens(token_list)
        token_list.insert(0, self.padding_token)
        token_list.append(self.unk_token)
        return token_list

    def _build_mapping_dicts(self, tokens: list):
        tokens = self._add_special_tokens(tokens)
        int_tokens = dict((i, c) for i, c in enumerate(tokens))
        tokens_int = dict((i, c) for c, i in enumerate(tokens))
        return int_tokens, tokens_int

    def build_vocab(self, train_dataset: pd.DataFrame):
        tokenized_dataset = self.tokenize_lyrics(train_dataset)
        unique_tokens = self._get_unique_tokens(tokenized_dataset)
        logger.info(f"Number of unique words in the dataset: {len(unique_tokens)}")
        int_tokens_mapping, tokens_int_mapping = self._build_mapping_dicts(unique_tokens)

        return int_tokens_mapping, tokens_int_mapping

    def _encode_text_with_padding(self, tokens: list, vocab: dict, max_length: int):
        encoded_text = []

        # Encode each token using the vocabulary
        for token in tokens:
            if token in vocab:
                encoded_text.append(vocab[token])
            else:
                # If the token is not in the vocabulary, use a special token or raise an error as needed
                encoded_text.append(vocab[self.unk_token])  # Use '<UNK>' for unknown tokens

        # Add padding tokens to achieve the desired length
        if len(encoded_text) < max_length:
            pad_length = max_length - len(encoded_text)
            encoded_text.extend([vocab[self.padding_token]] * pad_length)
        elif len(encoded_text) > max_length:
            encoded_text = encoded_text[:max_length]

        return encoded_text

    def _get_song_samples(self, lyrics: str, vocab: dict, seq_length: int):
        song_tokens = self._tokenize_text(lyrics)
        song_tokens = self._add_bos_eos_tokens(song_tokens)

        encoded_X, encoded_y = [], []
        for idx in range(0, len(song_tokens)-seq_length, 1):
            input_sequence = self._encode_text_with_padding(song_tokens[idx:idx+seq_length], vocab, seq_length)
            token_to_predict = song_tokens[idx+seq_length]
            if token_to_predict in vocab:
                output_sequence = vocab[token_to_predict]
            else:
                output_sequence = vocab[self.unk_token]
            encoded_X.append(input_sequence)
            encoded_y.append(output_sequence)

        return encoded_X, encoded_y

    def _get_encoded_samples(self, dataset: pd.DataFrame, vocab: dict, seq_length: int = 100):
        data_X, data_y = [], []
        for song in dataset.lyrics:
            song_Xs, song_ys = self._get_song_samples(song, vocab, seq_length)
            data_X.extend(song_Xs)
            data_y.extend(song_ys)

        return data_X, data_y

    def _one_hot_encode_labels(self, data_y, num_classes=None):
        if num_classes is None:
            num_classes = np.max(data_y) + 1

        one_hot_encoded = np.zeros((len(data_y), num_classes))
        one_hot_encoded[np.arange(len(data_y)), data_y] = 1

        return one_hot_encoded

    def get_samples(self, train_dataset: pd.DataFrame, test_dataset: pd.DataFrame):
        int_tokens_dict, tokens_int_dict = self.build_vocab(train_dataset)

        train_X, train_y = self._get_encoded_samples(train_dataset, tokens_int_dict, 100)
        test_X, test_y = self._get_encoded_samples(test_dataset, tokens_int_dict, 100)

        return train_X, self._one_hot_encode_labels(train_y), test_X, self._one_hot_encode_labels(test_y), tokens_int_dict

# %%
samples_generator = TextGenerationSamplesGenerator()
train_X, train_y, test_X, test_y, vocab = samples_generator.get_samples(train_dataset, test_dataset)
# Out:
# 2023-10-10 19:07:35.552 | INFO     | __main__:_get_unique_tokens:24 - Number of words in the dataset: 174022
# 2023-10-10 19:07:35.569 | INFO     | __main__:build_vocab:47 - Number of unique words in the dataset: 10666

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class LSTMTextGenerator(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(LSTMTextGenerator, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size-1) # Because train_X does not contain any [UNK]

    def forward(self, x, hidden):
        x = self.embedding(x)
        x, hidden = self.lstm(x, hidden)
        x = self.fc(x[:, -1, :])
        return x, hidden

def train_text_generator(model, train_loader, vocab_size, criterion, optimizer, num_epochs):
    model = model.to(device)
    model.train()
    for epoch in range(num_epochs):
        total_loss = 0.0
        hidden = None

        for inputs, targets in tqdm(train_loader):
            optimizer.zero_grad()
            inputs = inputs.to(device)
            targets = targets.to(device)
            outputs, hidden = model(inputs, hidden)

            with torch.no_grad():
                hidden = (hidden[0].detach(), hidden[1].detach())  # Detach the hidden state

            loss = criterion(outputs, targets) #criterion
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print(f"Epoch [{epoch + 1}/{num_epochs}] Loss: {total_loss / len(train_loader)}")

def generate_text(model, seed_text, max_length, vocab):
    model = model.to(device)
    model.eval()
    generated_text = seed_text

    with torch.no_grad():
        for _ in range(max_length):
            inputs = torch.tensor([vocab[token] if token in vocab else vocab["[UNK]"] for token in seed_text.split()], dtype=torch.long)
            inputs = inputs.to(device)
            inputs = inputs.unsqueeze(0)

            outputs, _ = model(inputs, None)
            predicted_word_idx = torch.argmax(outputs).item()

            predicted_word = next((word for word, idx in vocab.items() if idx == predicted_word_idx), None)
            if predicted_word is None:
                break

            generated_text += " " + predicted_word
            seed_text += " " + predicted_word

    return generated_text

# %%
vocab_size = len(vocab)
embedding_dim = 128
hidden_dim = 256
batch_size = 64
num_epochs = 30

# %%
model = LSTMTextGenerator(vocab_size, embedding_dim, hidden_dim)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_X = torch.tensor(train_X, dtype=torch.int64)
train_y = torch.tensor(train_y, dtype=torch.float32)

# %%
train_dataset = TensorDataset(train_X, train_y)

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

# %%
train_text_generator(model, train_loader, len(vocab), criterion, optimizer, num_epochs)

# %%
seed_text = "Once upon a time"
max_length = 500
generated_text = generate_text(model, seed_text, max_length, vocab)
print(generated_text)

# %% [markdown]
# ## 8.2. Solution 2: Zero-Shot Learning with Llama 2

# %% [markdown]
# ### 8.3.0. Importing Working Libraries

# %%
from transformers import AutoTokenizer
import transformers
import torch

# %%
model="meta-llama/Llama-2-7b-chat-hf"
tokenizer=AutoTokenizer.from_pretrained(model)
pipeline=transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
    )
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
prompt = "### Instruction: Complete the verses provided as input to write a new song, as if you were the famous singer and songwriter Taylor Swift. ### Input: Once upon a time\nIn a small town downriver\n"

# %%
sequences = pipeline(
    prompt,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=256,
)

# %%
sequences[0]['generated_text']

# %% [markdown]
# ## 8.3. Solution 3: Fine-Tuning Llama 2 for Lyrics Generation

# %% [markdown]
# ### 8.3.0. Importing Working Libraries

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer
from peft import LoraConfig
from trl import SFTTrainer
from transformers import TrainingArguments
from accelerate.utils import BnbQuantizationConfig
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cpu.so: undefined symbol: cadam32bit_grad_fp32

# %% [markdown]
# ### 8.3.1. Generating Training Data

# %% [markdown]
# For this stage, a dataset with a specific prompting structure for the Llama model to be trained had to be built. Here's the code used to do so:

# %%
class LyricsGenerationDatasetGenerator():
    def __init__(
        self,
        general_instruction: str = "Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request. ",
        instruction: str = "### Instruction: Complete the verses provided as input to write a new song, as if you were the famous singer and songwriter Taylor Swift. ",
        input_template: str = "### Input: ",
        output_template: str = "### Response: "
    ):
        self.general_instruction = general_instruction
        self.instruction = instruction
        self.input_template = input_template
        self.output_template = output_template

    def _create_input(self, complete_lyrics: str):
        verses = self._get_two_first_verses(complete_lyrics)
        return self.input_template + verses

    def _create_output(self, complete_lyrics: str):
        return self.output_template + complete_lyrics

    def _get_two_first_verses(self, lyrics: str):
        verses = lyrics.split("\n")
        return verses[0] + "\n" + verses[1] + "\n"

    def generate_prompt(self, lyrics: str):
        input_text = self._create_input(lyrics)
        output_text = self._create_output(lyrics)
        return self.general_instruction + self.instruction + input_text + " " + output_text

    def create_dataset(self, songs_df: pd.DataFrame):
        fine_tuning_dataset = pd.DataFrame()
        fine_tuning_dataset["input"] = songs_df.lyrics.apply(self._create_input)
        fine_tuning_dataset["output"] = songs_df.lyrics.apply(self._create_output)
        fine_tuning_dataset["text"] = songs_df.lyrics.apply(self.generate_prompt)

        return fine_tuning_dataset

# %%
preprocessor.get_preprocessed_data(True)
train_set_w_new_lines, test_set_w_new_lines = splitter.train_test_split(preprocessed_data)
fine_tuning_dataset_creator = LyricsGenerationDatasetGenerator()
train_prompting_dataset = fine_tuning_dataset_creator.create_dataset(train_set_w_new_lines)

# %%
train_prompting_dataset.head()
# Out:
#                                                input  \
# 0  ### Input: i see your face in my mind as i dri...
# 1  ### Input: you take a deep breath and you walk...
# 2  ### Input: once upon a time\ni believe it was ...
# 3  ### Input: we used to walk along the streets\n...
# 4  ### Input: theres something bout the way\nthe ...
#
#                                               output  \
# 0  ### Response: i see your face in my mind as i ...
# 1  ### Response: you take a deep breath and you w...
# 2  ### Response: once upon a time\ni believe it w...
# 3  ### Response: we used to walk along the street...
# 4  ### Response: theres something bout the way\nt...
#
#                                                 text
# 0  Below is an instruction that describes a task,...
# 1  Below is an instruction that describes a task,...
# 2  Below is an instruction that describes a task,...
# 3  Below is an instruction that describes a task,...
# 4  Below is an instruction that describes a task,...

# %% [markdown]
# The resultant dataset was uploaded to huggingface, and is accessible through the command in the following cell:

# %%
dataset = load_dataset("brunomaribeiro/ts_lyricsgenerationdataset")
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.87M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# ### 8.3.2. Fine-Tuning Llama 2

# %%
model_name = "TinyPixel/Llama-2-7B-bf16-sharded"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    trust_remote_code=True
)
model.config.use_cache = False

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token

# %%
lora_alpha = 16
lora_dropout = 0.1
lora_r = 64

peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj","v_proj"]
)

# %%
output_dir = "./results"
per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = "paged_adamw_32bit"
save_steps = 10
logging_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
max_steps = 120
warmup_ratio = 0.03
lr_scheduler_type = "constant"

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    fp16=True,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=True,
    lr_scheduler_type=lr_scheduler_type,
)

# %%
max_seq_length = 512

trainer = SFTTrainer(
    model=model,
    train_dataset=dataset['train'],
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
)

# %%
for name, module in trainer.model.named_modules():
    if "norm" in name:
        module = module.to(torch.float32)

# %%
trainer.train()

# %% [markdown]
# ### 8.3.3. Inference

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    # torch_dtype=torch.bfloat16,
    torch_dtype=torch.float16,
    trust_remote_code=True,
    device_map="auto",
)

# %%
sequences = pipeline(
    ["Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request. ### Instruction: Complete the verses provided as input to write a new song, as if you were the famous singer and songwriter Taylor Swift. ### Input: Once upon a time\nIn a small town downriver\n"],
    max_length=500,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)

# %%
sequences[0]["generated_text"]

# %% [markdown]
# # 9. Performance Evaluation

# %% [markdown]
# Evaluating the performance of the developed techniques goes beyond a simple eye-ball test. Automated Text Generation Metrics such as Perplexity or BLEU score should be applied. The different approaches should be evaluated by computing each of these metrics against every pair target_text-generated_text, created upon inference against the test set previously splitted.

# %% [markdown]
# ## 9.0. Import Working Libraries

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score

# %% [markdown]
# ## 9.1. Evaluation Metrics

# %% [markdown]
# ### 9.1.1. BLEU score

# %%
def calculate_bleu(target_text, generated_text):
    # Tokenize the target and generated texts
    target_tokens = nltk.word_tokenize(target_text.lower())
    generated_tokens = nltk.word_tokenize(generated_text.lower())

    # Calculate BLEU score
    bleu_score = sentence_bleu([target_tokens], generated_tokens)
    return bleu_score

# %% [markdown]
# ### 9.1.2. ROUGE

# %%
def calculate_rouge_n(target_text, generated_text, n=2):
    scorer = rouge_scorer.RougeScorer(['rouge{}-n'.format(n)])
    scores = scorer.score(target_text, generated_text)
    return scores['rouge{}-n'.format(n)].fmeasure

# %% [markdown]
# ### 9.1.3. METEOR

# %%
def calculate_meteor(target_text, generated_text):
    meteor = meteor_score([target_text], generated_text)
    return meteor

# %% [markdown]
# # 10. Final Considerations

# %% [markdown]
# Unfortunately, I ran out of GPU resources halfway through the development of the solutions. This made me lose a lot of time, and prevented me from testing the final version of the notebook. I also couldn't finish my plan for this task, which consisted of:
#
# 1. Building Solid Loading and Pre-processing Modules (Complete);
# 2. Take on a quick Exploratory Data Analysis task (I kept looking and learning from the data, but I couldn't report any of my findings in terms of data analysis);
# 3. Come up with an appropriate splitting strategy (I wanted to think more about this after I finish, although I considered that isolating all the songs from a single album would be a good test for the different solutions);
# 4. Test 3 different approaches to the problem: Traditional, Prompt-based, and Fine-tuning. (Although I present the code for all three, I couldn't run enough tests. Nevertheless, I believe that they should work. Through the eye-ball test, the Llama-2 based approaches performed much better.)
# 5. Perform a thorough performance evaluation, including both human-based and automated evaluation techniques. (I present some of the metrics I intended to use, but I could not even run inference loops against the test set)
# 6. Present good practices and clean code throughout the notebook, including typing and appropriate commenting. (Although I started this way, by the end of the notebook everything got a bit messy, due to time contraints.)
